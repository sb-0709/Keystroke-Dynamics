# %% [markdown]
# # Loading of dataset

# %%
import pandas as pd
df = pd.read_csv('C:/Users/Sanskriti/Downloads/DSL-StrongPasswordData.csv')
df.head()
# Out:
#   subject  sessionIndex  rep  H.period  DD.period.t  UD.period.t     H.t  \
# 0    s002             1    1    0.1491       0.3979       0.2488  0.1069
# 1    s002             1    2    0.1111       0.3451       0.2340  0.0694
# 2    s002             1    3    0.1328       0.2072       0.0744  0.0731
# 3    s002             1    4    0.1291       0.2515       0.1224  0.1059
# 4    s002             1    5    0.1249       0.2317       0.1068  0.0895
#
#    DD.t.i  UD.t.i     H.i  ...     H.a  DD.a.n  UD.a.n     H.n  DD.n.l  \
# 0  0.1674  0.0605  0.1169  ...  0.1349  0.1484  0.0135  0.0932  0.3515
# 1  0.1283  0.0589  0.0908  ...  0.1412  0.2558  0.1146  0.1146  0.2642
# 2  0.1291  0.0560  0.0821  ...  0.1621  0.2332  0.0711  0.1172  0.2705
# 3  0.2495  0.1436  0.1040  ...  0.1457  0.1629  0.0172  0.0866  0.2341
# 4  0.1676  0.0781  0.0903  ...  0.1312  0.1582  0.0270  0.0884  0.2517
#
#    UD.n.l     H.l  DD.l.Return  UD.l.Return  H.Return
# ...

# %%
df.describe()
# Out:
#        sessionIndex           rep      H.period   DD.period.t   UD.period.t  \
# count  20400.000000  20400.000000  20400.000000  20400.000000  20400.000000
# mean       4.500000     25.500000      0.093379      0.264148      0.170769
# std        2.291344     14.431223      0.029626      0.220534      0.226836
# min        1.000000      1.000000      0.001400      0.018700     -0.235800
# 25%        2.750000     13.000000      0.074400      0.146900      0.049800
# 50%        4.500000     25.500000      0.089500      0.205950      0.108700
# 75%        6.250000     38.000000      0.107900      0.306450      0.212400
# max        8.000000     50.000000      0.376100     12.506100     12.451700
#
#                 H.t        DD.t.i        UD.t.i           H.i        DD.i.e  \
# count  20400.000000  20400.000000  20400.000000  20400.000000  20400.000000
# mean       0.085727      0.169085      0.083358      0.081565      0.159372
# ...

# %% [markdown]
# # Formatting of Dataset

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def load_data():
    df = pd.read_csv('C:/Users/Sanskriti/Downloads/DSL-StrongPasswordData.csv')
    
    H_columns  = [col for col in df.columns if col.startswith('H')]
    DD_columns = [col for col in df.columns if col.startswith('DD')]
    UD_columns = [col for col in df.columns if col.startswith('UD')]

    data = {}
    data['total'] = df.drop(columns=['subject', 'sessionIndex', 'rep'])
    data['H']     = df[H_columns]
    data['DD']    = df[DD_columns]
    data['UD']    = df[UD_columns]
    
    return data, df['subject'].values

# %% [markdown]
# # Visualisation of Dataset

# %% [markdown]
# ### 1. Keydown- Keydown

# %% [raw]
#  This is a classical keystroke feature which consists of the durations between the key-down of one key to the key-down of the     next key.
#  It is denoted as 'DD' in this data set.

# %%
data, y = load_data()

# One hot encoding
Y = pd.get_dummies(y).values
n_classes = Y.shape[1]

df_plot = data['DD'].copy()
df_plot['subject'] = y
df_plot = df_plot.groupby('subject').mean()
df_plot.iloc[:8].T.plot(figsize=(14, 7), title='Average Keydown-Keydown Duration')
plt.xlabel('Key Index')
plt.ylabel('Duration');

# %% [markdown]
# ### 2. Pressure Duration (Hold)

# %% [raw]
#  This keystroke feature consists of the durations of key-down to key-up of a single key.
#  It is denoted as H in the data set.

# %%
df_plot = data['H'].copy()
df_plot['subject'] = y
df_plot = df_plot.groupby('subject').mean()
df_plot.iloc[:8].T.plot(figsize=(14, 7), title='Average Pressure Duration')
plt.xlabel('Key Index')
plt.ylabel('Duration');

# %% [markdown]
# ### 3. Keyup- Keydown

# %% [raw]
#  This keystoke feature consists of the duration between the release of one key and the press of the next key.
#  It is denoted by 'UD' in the dataset.

# %%
df_plot = data['UD'].copy()
df_plot['subject'] = y
df_plot = df_plot.groupby('subject').mean()
df_plot.iloc[:8].T.plot(figsize=(14, 7), title='Average Keyup-Keydown Duration')
plt.xlabel('Key Index')
plt.ylabel('Duration');
